# %%
import pandas as pd
import json

# %%
with open('melbourneObservations.json', 'r') as f:
    json_data = json.load(f)

forecastData = json_data["product"]['observations']['station']
df_forecast = pd.json_normalize(forecastData, sep= '_')

# %%
df_forecast.columns
# Out:
# Index(['@wmo-id', '@bom-id', '@tz', '@stn-name', '@stn-height', '@type',
#        '@lat', '@lon', '@forecast-district-id', '@description',
#        'period_@index', 'period_@time-utc', 'period_@time-local',
#        'period_@wind-src', 'period_level_@index', 'period_level_@type',
#        'period_level_element'],
#       dtype='object')

# %%
df_forecast[['@stn-name','@stn-height','period_level_element']].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_a905b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a905b_level0_col0" class="col_heading level0 col0" >@stn-name</th>
#       <th id="T_a905b_level0_col1" class="col_heading level0 col1" >@stn-height</th>
#       <th id="T_a905b_level0_col2" class="col_heading level0 col2" >period_level_element</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a905b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a905b_row0_col0" class="data row0 col0" >MELBOURNE (OLYMPIC PARK)</td>
#       <td id="T_a905b_row0_col1" class="data row0 col1" >7.53</td>
#       <td id="T_a905b_row0_col2" class="data row0 col2" >[{'@units': 'Celsius', '@type': 'apparent_temp', '#text': '16.5'}, {'@units': 'Celsius', '@type': 'delta_t', '#text': '6.5'}, {'@units': 'km/h', '@type': 'gust_kmh', '#text': '20'}, {'@units': 'knots', '@type': 'wind_gust_spd', '#text': '11'}, {'@units': 'Celsius', '@type': 'air_temperature', '#text': '20.0'}, {'@units': 'Celsius', '@type': 'dew_point', '#text': '7.1'}, {'@units': 'hPa', '@type': 'pres', '#text': '1019.4'}, {'@units': 'hPa', '@type': 'msl_pres', '#text': '1019.4'}, {'@units': 'hPa', '@type': 'qnh_pres', '#text': '1019.4'}, {'@units': '%', '@type': 'rel-humidity', '#text': '43'}, {'@units': 'km', '@type': 'vis_km', '#text': '65'}, {'@type': 'wind_dir', '#text': 'ESE'}, {'@units': 'deg', '@type': 'wind_dir_deg', '#text': '108'}, {'@units': 'km/h', '@type': 'wind_spd_kmh', '#text': '15'}, {'@units': 'knots', '@type': 'wind_spd', '#text': '8'}, {'@start-time-local': '2025-03-31T09:00:00+11:00', '@end-time-local': '2025-03-31T18:22:00+11:00', '@duration': '562', '@start-time-utc': '2025-03-30T22:00:00+00:00', '@end-time-utc': '2025-03-31T07:22:00+00:00', '@units': 'mm', '@type': 'rainfall', '#text': '0.0'}, {'@start-time-local': '2025-03-30T09:00:00+11:00', '@end-time-local': '2025-03-31T09:00:00+11:00', '@duration': '1440', '@start-time-utc': '2025-03-29T22:00:00+00:00', '@end-time-utc': '2025-03-30T22:00:00+00:00', '@units': 'mm', '@type': 'rainfall_24hr', '#text': '0.0'}, {'@start-time-local': '2025-03-31T06:00:00+11:00', '@end-time-local': '2025-03-31T21:00:00+11:00', '@start-time-utc': '2025-03-30T19:00:00+00:00', '@end-time-utc': '2025-03-31T10:00:00+00:00', '@units': 'Celsius', '@type': 'maximum_air_temperature', '@instance': 'running', '@time-utc': '2025-03-31T05:31:00+00:00', '@time-local': '2025-03-31T16:31:00+11:00', '#text': '21.9'}, {'@start-time-local': '2025-03-31T18:00:00+11:00', '@end-time-local': '2025-04-01T09:00:00+11:00', '@start-time-utc': '2025-03-31T07:00:00+00:00', '@end-time-utc': '2025-03-31T22:00:00+00:00', '@units': 'Celsius', '@type': 'minimum_air_temperature', '@instance': 'running', '@time-utc': '2025-03-31T07:20:00+00:00', '@time-local': '2025-03-31T18:20:00+11:00', '#text': '19.9'}, {'@start-time-local': '2025-03-31T00:00:00+11:00', '@end-time-local': '2025-04-01T00:00:00+11:00', '@start-time-utc': '2025-03-30T13:00:00+00:00', '@end-time-utc': '2025-03-31T13:00:00+00:00', '@units': 'knots', '@type': 'maximum_gust_spd', '@instance': 'running', '@time-utc': '2025-03-30T23:58:00+00:00', '@time-local': '2025-03-31T10:58:00+11:00', '#text': '22'}, {'@start-time-local': '2025-03-31T00:00:00+11:00', '@end-time-local': '2025-04-01T00:00:00+11:00', '@start-time-utc': '2025-03-30T13:00:00+00:00', '@end-time-utc': '2025-03-31T13:00:00+00:00', '@units': 'km/h', '@type': 'maximum_gust_kmh', '@instance': 'running', '@time-utc': '2025-03-30T23:58:00+00:00', '@time-local': '2025-03-31T10:58:00+11:00', '#text': '41'}, {'@start-time-local': '2025-03-31T00:00:00+11:00', '@end-time-local': '2025-04-01T00:00:00+11:00', '@start-time-utc': '2025-03-30T13:00:00+00:00', '@end-time-utc': '2025-03-31T13:00:00+00:00', '@type': 'maximum_gust_dir', '@instance': 'running', '@time-utc': '2025-03-30T23:58:00+00:00', '@time-local': '2025-03-31T10:58:00+11:00', '#text': 'ESE'}]</td>
#     </tr>
#     <tr>
#       <th id="T_a905b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a905b_row1_col0" class="data row1 col0" >MELBOURNE AIRPORT</td>
#       <td id="T_a905b_row1_col1" class="data row1 col1" >113.40</td>
#       <td id="T_a905b_row1_col2" class="data row1 col2" >[{'@units': 'Celsius', '@type': 'apparent_temp', '#text': '12.5'}, {'@type': 'cloud', '#text': 'Mostly clear'}, {'@type': 'cloud_oktas', '#text': '2'}, {'@units': 'Celsius', '@type': 'delta_t', '#text': '6.0'}, {'@units': 'km/h', '@type': 'gust_kmh', '#text': '33'}, {'@units': 'knots', '@type': 'wind_gust_spd', '#text': '18'}, {'@units': 'Celsius', '@type': 'air_temperature', '#text': '18.9'}, {'@units': 'Celsius', '@type': 'dew_point', '#text': '7.0'}, {'@units': 'hPa', '@type': 'pres', '#text': '1019.3'}, {'@units': 'hPa', '@type': 'msl_pres', '#text': '1019.3'}, {'@units': 'hPa', '@type': 'qnh_pres', '#text': '1019.5'}, {'@units': '%', '@type': 'rel-humidity', '#text': '46'}, {'@units': 'km', '@type': 'vis_km', '#text': '48'}, {'@type': 'wind_dir', '#text': 'SE'}, {'@units': 'deg', '@type': 'wind_dir_deg', '#text': '137'}, {'@units': 'km/h', '@type': 'wind_spd_kmh', '#text': '30'}, {'@units': 'knots', '@type': 'wind_spd', '#text': '16'}, {'@start-time-local': '2025-03-31T09:00:00+11:00', '@end-time-local': '2025-03-31T18:22:00+11:00', '@duration': '562', '@start-time-utc': '2025-03-30T22:00:00+00:00', '@end-time-utc': '2025-03-31T07:22:00+00:00', '@units': 'mm', '@type': 'rainfall', '#text': '0.0'}, {'@start-time-local': '2025-03-30T09:00:00+11:00', '@end-time-local': '2025-03-31T09:00:00+11:00', '@duration': '1440', '@start-time-utc': '2025-03-29T22:00:00+00:00', '@end-time-utc': '2025-03-30T22:00:00+00:00', '@units': 'mm', '@type': 'rainfall_24hr', '#text': '0.0'}, {'@start-time-local': '2025-03-31T06:00:00+11:00', '@end-time-local': '2025-03-31T21:00:00+11:00', '@start-time-utc': '2025-03-30T19:00:00+00:00', '@end-time-utc': '2025-03-31T10:00:00+00:00', '@units': 'Celsius', '@type': 'maximum_air_temperature', '@instance': 'running', '@time-utc': '2025-03-31T04:55:00+00:00', '@time-local': '2025-03-31T15:55:00+11:00', '#text': '21.7'}, {'@start-time-local': '2025-03-31T18:00:00+11:00', '@end-time-local': '2025-04-01T09:00:00+11:00', '@start-time-utc': '2025-03-31T07:00:00+00:00', '@end-time-utc': '2025-03-31T22:00:00+00:00', '@units': 'Celsius', '@type': 'minimum_air_temperature', '@instance': 'running', '@time-utc': '2025-03-31T07:20:00+00:00', '@time-local': '2025-03-31T18:20:00+11:00', '#text': '18.8'}, {'@start-time-local': '2025-03-31T00:00:00+11:00', '@end-time-local': '2025-04-01T00:00:00+11:00', '@start-time-utc': '2025-03-30T13:00:00+00:00', '@end-time-utc': '2025-03-31T13:00:00+00:00', '@units': 'knots', '@type': 'maximum_gust_spd', '@instance': 'running', '@time-utc': '2025-03-31T04:42:00+00:00', '@time-local': '2025-03-31T15:42:00+11:00', '#text': '26'}, {'@start-time-local': '2025-03-31T00:00:00+11:00', '@end-time-local': '2025-04-01T00:00:00+11:00', '@start-time-utc': '2025-03-30T13:00:00+00:00', '@end-time-utc': '2025-03-31T13:00:00+00:00', '@units': 'km/h', '@type': 'maximum_gust_kmh', '@instance': 'running', '@time-utc': '2025-03-31T04:42:00+00:00', '@time-local': '2025-03-31T15:42:00+11:00', '#text': '48'}, {'@start-time-local': '2025-03-31T00:00:00+11:00', '@end-time-local': '2025-04-01T00:00:00+11:00', '@start-time-utc': '2025-03-30T13:00:00+00:00', '@end-time-utc': '2025-03-31T13:00:00+00:00', '@type': 'maximum_gust_dir', '@instance': 'running', '@time-utc': '2025-03-31T04:42:00+00:00', '@time-local': '2025-03-31T15:42:00+11:00', '#text': 'SE'}]</td>
#     </tr>
#     <tr>
#       <th id="T_a905b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a905b_row2_col0" class="data row2 col0" >AVALON AIRPORT</td>
#       <td id="T_a905b_row2_col1" class="data row2 col1" >10.60</td>
#       <td id="T_a905b_row2_col2" class="data row2 col2" >[{'@units': 'Celsius', '@type': 'apparent_temp', '#text': '11.8'}, {'@type': 'cloud', '#text': 'Clear'}, {'@t
